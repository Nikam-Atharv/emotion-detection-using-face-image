# %% [markdown]
# # Emotion Detection Using CNN

# %%
#Connecting to drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

import sys, os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam
from keras.regularizers import l2

# %% [markdown]
# ## Importing dataset

# %%
data = pd.read_csv('/content/gdrive/My Drive/projectytdrive/fer2013.csv')

# %%
width, height = 48, 48

datapoints = data['pixels'].tolist()


X = []
for s in datapoints:
    xx = [int(xp) for xp in s.split(' ')]
    xx = np.asarray(xx).reshape(width, height)
    X.append(xx.astype('float32'))

X = np.asarray(X)
X = np.expand_dims(X, -1)

y = pd.get_dummies(data['emotion']).values

np.save('d_X', X)
np.save('lab', y)

print("Preprocessing Done")
print("Number of Features: "+str(len(X[0])))
print("Number of Labels: "+ str(len(y[0])))
print("Number of examples in dataset:"+str(len(X)))
print("X,y stored in d_X.npy and lab.npy respectively")
# Out:
# Preprocessing Done
# Number of Features: 48
# Number of Labels: 7
# Number of examples in dataset:35887
# X,y stored in d_X.npy and lab.npy respectively

# %%
num_features = 64
num_labels = 7
batch_size = 64
epochs = 50
width, height = 48, 48

x = np.load('./d_X.npy')
y = np.load('./lab.npy')

x -= np.mean(x, axis=0)
x /= np.std(x, axis=0)


X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=41)


np.save('modXtest', X_test)
np.save('modytest', y_test)


model = Sequential()

model.add(Conv2D(num_features, kernel_size=(3, 3), activation='relu', input_shape=(width, height, 1), data_format='channels_last', kernel_regularizer=l2(0.01)))
model.add(Conv2D(num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())

model.add(Dense(2*2*2*num_features, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(2*2*num_features, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(2*num_features, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(num_labels, activation='softmax'))

model.summary()
model.compile(loss=categorical_crossentropy,
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),
              metrics=['accuracy'])


model.fit(np.array(X_train), np.array(y_train),
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(np.array(X_valid), np.array(y_valid)),
          shuffle=True)


fer_json = model.to_json()
with open("fer.json", "w") as json_file:
    json_file.write(fer_json)
model.save_weights("fer.h5")
print("Saved model to disk")
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_88 (Conv2D)           (None, 46, 46, 64)        640
# _________________________________________________________________
# conv2d_89 (Conv2D)           (None, 64, 46, 64)        26560
# _________________________________________________________________
# batch_normalization_53 (Batc (None, 64, 46, 64)        256
# _________________________________________________________________
# max_pooling2d_44 (MaxPooling (None, 64, 23, 32)        0
# _________________________________________________________________
# dropout_53 (Dropout)         (None, 64, 23, 32)        0
# _________________________________________________________________
# conv2d_90 (Conv2D)           (None, 128, 23, 32)       73856
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 128, 23, 32)       128
# _________________________________________________________________
# conv2d_91 (Conv2D)           (None, 128, 23, 32)       147584
# _________________________________________________________________
# batch_normalization_55 (Batc (None, 128, 23, 32)       128
# _________________________________________________________________
# max_pooling2d_45 (MaxPooling (None, 128, 11, 16)       0
# _________________________________________________________________
# dropout_54 (Dropout)         (None, 128, 11, 16)       0
# _________________________________________________________________
# conv2d_92 (Conv2D)           (None, 256, 11, 16)       295168
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 256, 11, 16)       64
# _________________________________________________________________
# conv2d_93 (Conv2D)           (None, 256, 11, 16)       590080
# _________________________________________________________________
# batch_normalization_57 (Batc (None, 256, 11, 16)       64
# _________________________________________________________________
# max_pooling2d_46 (MaxPooling (None, 256, 5, 8)         0
# _________________________________________________________________
# dropout_55 (Dropout)         (None, 256, 5, 8)         0
# _________________________________________________________________
# conv2d_94 (Conv2D)           (None, 512, 5, 8)         1180160
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 512, 5, 8)         32
# _________________________________________________________________
# conv2d_95 (Conv2D)           (None, 512, 5, 8)         2359808
# _________________________________________________________________
# batch_normalization_59 (Batc (None, 512, 5, 8)         32
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 512, 2, 4)         0
# _________________________________________________________________
# dropout_56 (Dropout)         (None, 512, 2, 4)         0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_36 (Dense)             (None, 512)               2097664
# _________________________________________________________________
# dropout_57 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_58 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_59 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_39 (Dense)             (None, 7)                 903
# =================================================================
# Total params: 6,937,351
# Trainable params: 6,936,999
# Non-trainable params: 352
# _________________________________________________________________
# Epoch 1/50
# 455/455 [==============================] - 28s 60ms/step - loss: 2.2994 - accuracy: 0.2088 - val_loss: 1.8149 - val_accuracy: 0.2594
# Epoch 2/50
# 455/455 [==============================] - 27s 58ms/step - loss: 1.8369 - accuracy: 0.2475 - val_loss: 1.7959 - val_accuracy: 0.2666
# Epoch 3/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.8196 - accuracy: 0.2514 - val_loss: 1.7933 - val_accuracy: 0.2594
# Epoch 4/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.8011 - accuracy: 0.2536 - val_loss: 1.7615 - val_accuracy: 0.2861
# Epoch 5/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.7734 - accuracy: 0.2742 - val_loss: 1.7222 - val_accuracy: 0.3009
# Epoch 6/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.7425 - accuracy: 0.2879 - val_loss: 1.7008 - val_accuracy: 0.3068
# Epoch 7/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.7287 - accuracy: 0.2944 - val_loss: 1.6890 - val_accuracy: 0.3050
# Epoch 8/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.6944 - accuracy: 0.3116 - val_loss: 1.6336 - val_accuracy: 0.3480
# Epoch 9/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.6619 - accuracy: 0.3378 - val_loss: 1.5778 - val_accuracy: 0.3625
# Epoch 10/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.6278 - accuracy: 0.3641 - val_loss: 1.5579 - val_accuracy: 0.3833
# Epoch 11/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.6007 - accuracy: 0.3779 - val_loss: 1.5421 - val_accuracy: 0.4037
# Epoch 12/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.5762 - accuracy: 0.3855 - val_loss: 1.5074 - val_accuracy: 0.4028
# Epoch 13/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.5463 - accuracy: 0.4008 - val_loss: 1.4820 - val_accuracy: 0.4173
# Epoch 14/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.5176 - accuracy: 0.4098 - val_loss: 1.5510 - val_accuracy: 0.3749
# Epoch 15/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.5182 - accuracy: 0.4204 - val_loss: 1.4406 - val_accuracy: 0.4384
# Epoch 16/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.5084 - accuracy: 0.4162 - val_loss: 1.4787 - val_accuracy: 0.4173
# Epoch 17/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.4783 - accuracy: 0.4324 - val_loss: 1.4581 - val_accuracy: 0.4325
# Epoch 18/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.4610 - accuracy: 0.4374 - val_loss: 1.4342 - val_accuracy: 0.4384
# Epoch 19/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.4449 - accuracy: 0.4422 - val_loss: 1.4470 - val_accuracy: 0.4288
# Epoch 20/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.4375 - accuracy: 0.4489 - val_loss: 1.4223 - val_accuracy: 0.4523
# Epoch 21/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.4178 - accuracy: 0.4562 - val_loss: 1.3830 - val_accuracy: 0.4641
# Epoch 22/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.3899 - accuracy: 0.4664 - val_loss: 1.4001 - val_accuracy: 0.4582
# Epoch 23/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.3826 - accuracy: 0.4680 - val_loss: 1.3962 - val_accuracy: 0.4594
# Epoch 24/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.3546 - accuracy: 0.4822 - val_loss: 1.3898 - val_accuracy: 0.4641
# Epoch 25/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.3350 - accuracy: 0.4920 - val_loss: 1.3473 - val_accuracy: 0.4811
# Epoch 26/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.3300 - accuracy: 0.4950 - val_loss: 1.3542 - val_accuracy: 0.4854
# Epoch 27/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.3126 - accuracy: 0.4984 - val_loss: 1.3915 - val_accuracy: 0.4656
# Epoch 28/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.2946 - accuracy: 0.5086 - val_loss: 1.3738 - val_accuracy: 0.4724
# Epoch 29/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.2798 - accuracy: 0.5138 - val_loss: 1.3702 - val_accuracy: 0.4737
# Epoch 30/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.2713 - accuracy: 0.5185 - val_loss: 1.3326 - val_accuracy: 0.4885
# Epoch 31/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.2558 - accuracy: 0.5238 - val_loss: 1.3297 - val_accuracy: 0.5022
# Epoch 32/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.2343 - accuracy: 0.5318 - val_loss: 1.3366 - val_accuracy: 0.4944
# Epoch 33/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.2269 - accuracy: 0.5348 - val_loss: 1.3361 - val_accuracy: 0.4799
# Epoch 34/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.2103 - accuracy: 0.5478 - val_loss: 1.3483 - val_accuracy: 0.4907
# Epoch 35/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.2108 - accuracy: 0.5451 - val_loss: 1.3030 - val_accuracy: 0.5056
# Epoch 36/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.1824 - accuracy: 0.5541 - val_loss: 1.3836 - val_accuracy: 0.4913
# Epoch 37/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.1688 - accuracy: 0.5638 - val_loss: 1.3793 - val_accuracy: 0.5167
# Epoch 38/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.1526 - accuracy: 0.5698 - val_loss: 1.3826 - val_accuracy: 0.5071
# Epoch 39/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.1432 - accuracy: 0.5742 - val_loss: 1.2962 - val_accuracy: 0.5127
# Epoch 40/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.1290 - accuracy: 0.5819 - val_loss: 1.3278 - val_accuracy: 0.5232
# Epoch 41/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.1086 - accuracy: 0.5885 - val_loss: 1.3305 - val_accuracy: 0.5118
# Epoch 42/50
# 455/455 [==============================] - 26s 57ms/step - loss: 1.1071 - accuracy: 0.5912 - val_loss: 1.3377 - val_accuracy: 0.5285
# Epoch 43/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.0892 - accuracy: 0.5938 - val_loss: 1.3114 - val_accuracy: 0.5285
# Epoch 44/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.0595 - accuracy: 0.6047 - val_loss: 1.3196 - val_accuracy: 0.5288
# Epoch 45/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.0547 - accuracy: 0.6094 - val_loss: 1.3568 - val_accuracy: 0.5226
# Epoch 46/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.0388 - accuracy: 0.6146 - val_loss: 1.3542 - val_accuracy: 0.5288
# Epoch 47/50
# 455/455 [==============================] - 26s 58ms/step - loss: 1.0192 - accuracy: 0.6252 - val_loss: 1.3201 - val_accuracy: 0.5353
# Epoch 48/50
# 455/455 [==============================] - 26s 58ms/step - loss: 0.9940 - accuracy: 0.6367 - val_loss: 1.3750 - val_accuracy: 0.5319
# Epoch 49/50
# 455/455 [==============================] - 26s 58ms/step - loss: 0.9886 - accuracy: 0.6354 - val_loss: 1.3583 - val_accuracy: 0.5341
# Epoch 50/50
# 455/455 [==============================] - 26s 57ms/step - loss: 0.9681 - accuracy: 0.6442 - val_loss: 1.3396 - val_accuracy: 0.5381
# Saved model to disk
